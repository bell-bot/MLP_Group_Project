# %%
# %matplotlib inline

# %%
from alignments import Aligner

# %%
x = Aligner()
TED_sample_dict = x.TED.__getitem__(2)
sample_timestamps, trellis, word_segments = x.align_current_audio_chunk(TED_sample_dict)
waveform =  torch.from_numpy(TED_sample_dict["waveform"])
# Out:
# Preparing Ted Dataset...
# Preparing MSWC Dataset...
# Reading /Users/Wassim/Documents/Year 4/MLP/CW3:4/MLP_Group_Project/src/Data/keywords.csv
# ----- KEYWORDS CSV NOT FOUND -----
# Side note: The python script assumes that the TED Sample ID column is in 1
# Last TED Sample ID Read: 69
# b'for,69,train,AJJacobs_2007P,for/common_voice_en_18166101__2.opus,41.927,48.7773125,0.9160292237997055\r\n'
# ----

# %%
x.display_segment(0, waveform, trellis, word_segments)
# Out:
# <s><unk> (0.50): 0.060 - 0.100 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x.display_segment(1,waveform, trellis, word_segments)
# Out:
# FIRST (1.00): 0.181 - 0.442 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x.display_segment(2,waveform,trellis, word_segments)
# Out:
# LEARNED (0.84): 0.542 - 0.944 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x.display_segment(3,waveform,trellis, word_segments)
# Out:
# THAT (0.90): 1.526 - 1.707 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x.display_segment(4,waveform,trellis, word_segments)
# Out:
# MY (1.00): 1.767 - 1.908 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x.display_segment(5,waveform,trellis, word_segments)
# Out:
# SON (0.95): 2.008 - 2.309 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
